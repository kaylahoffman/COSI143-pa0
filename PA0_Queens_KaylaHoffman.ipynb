# %% [markdown]
# # Kayla Hoffman
# COSI 143 - Programming Assignment 0

# %% [markdown]
# Queens data set

# %% [markdown]
# Loading and Cleaning the data

# %%
#load the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#load the data into a data frame and print the first few entries
df = pd.read_excel('rollingsales_queens.xls', header = 4)
df.head()
# Out:
#    BOROUGH               NEIGHBORHOOD  \
# 0        4  AIRPORT LA GUARDIA
# 1        4  AIRPORT LA GUARDIA
# 2        4  AIRPORT LA GUARDIA
# 3        4  AIRPORT LA GUARDIA
# 4        4  AIRPORT LA GUARDIA
#
#                         BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  01  ONE FAMILY HOMES                                            1    949
# 1  01  ONE FAMILY HOMES                                            1    949
# 2  01  ONE FAMILY HOMES                                            1    976
# 3  01  ONE FAMILY HOMES                                            1    976
# 4  01  ONE FAMILY HOMES                                            1    976
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0   30                                  A5
# 1   44                                  A5
# 2   23                                  A5
# 3   33                                  A5
# 4   55                                  A5
#
#                                      ADDRESS APART\nMENT\nNUMBER  ...  \
# 0  19-40 81ST STREET                                              ...
# 1  19-68 81ST   STREET                                            ...
# 2  21-36 81ST   STREET                                            ...
# 3  21-56 81ST STREET                                              ...
# 4  21-33 80TH ST.                                                 ...
#
#    RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                  1                 0            1              1800
# 1                  1                 0            1              1800
# 2                  1                 0            1              1800
# 3                  1                 0            1              1800
# 4                  1                 0            1              1800
#
#    GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0               1530        1945                          1
# 1               1224        1945                          1
# 2               1224        1950                          1
# 3               1224        1950                          1
# 4               1224        1950                          1
#
#    BUILDING CLASS AT TIME OF SALE SALE\nPRICE  SALE DATE
# 0                              A5      620000 2013-05-13
# 1                              A5           0 2012-10-05
# 2                              A5      505000 2013-02-13
# 3                              A5           0 2013-07-25
# 4                              A5           0 2012-10-10
#
# [5 rows x 21 columns]

# %%
#display the data types for the attributes
df.dtypes
# Out:
# BOROUGH                                    int64
# NEIGHBORHOOD                              object
# BUILDING CLASS CATEGORY                   object
# TAX CLASS AT PRESENT                      object
# BLOCK                                      int64
# LOT                                        int64
# EASE-MENT                                 object
# BUILDING CLASS AT PRESENT                 object
# ADDRESS                                   object
# APART\nMENT\nNUMBER                       object
# ZIP CODE                                   int64
# RESIDENTIAL UNITS                          int64
# COMMERCIAL UNITS                           int64
# TOTAL UNITS                                int64
# LAND SQUARE FEET                           int64
# GROSS SQUARE FEET                          int64
# YEAR BUILT                                 int64
# TAX CLASS AT TIME OF SALE                  int64
# BUILDING CLASS AT TIME OF SALE            object
# SALE\nPRICE                                int64
# SALE DATE                         datetime64[ns]
# dtype: object

# %% [markdown]
# Exploring the Data set

# %%
#print histogram with sale price as y-axis
num_bins = 100
plt.hist(df['SALE\nPRICE'], num_bins,facecolor='blue', alpha=0.7)
plt.xlabel('SALE\nPRICE') # label x-axis
plt.ylabel('Frequency') # label y-axis
plt.show()

# %%
#drops the rows with a sale price of 0
df.drop(df.loc[df['SALE\nPRICE']==0].index, inplace=True)
df.describe()
# Out:
#        BOROUGH         BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  \
# count  15587.0  15587.000000  15587.000000  15587.000000       15587.000000
# mean       4.0   6234.364919    197.444922  11359.995445           1.648425
# std        0.0   4181.791432    423.137267    214.069335          12.407681
# min        4.0      6.000000      1.000000      0.000000           0.000000
# 25%        4.0   2382.000000     14.000000  11358.000000           0.000000
# 50%        4.0   5512.000000     37.000000  11374.000000           1.000000
# 75%        4.0   9532.000000     76.000000  11417.000000           2.000000
# max        4.0  16320.000000   7501.000000  11694.000000        1091.000000
#
#        COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# count      15587.000000  15587.000000      1.558700e+04       1.558700e+04
# mean           0.204209      1.858408      2.650196e+03       2.094382e+03
# std           10.181539     16.056451      1.494111e+04       1.479547e+04
# min            0.000000      0.000000      0.000000e+00       0.000000e+00
# 25%            0.000000      0.000000      0.000000e+00       0.000000e+00
# 50%            0.000000      1.000000      2.000000e+03       1.248000e+03
# 75%            0.000000      2.000000      3.125000e+03       1.980000e+03
# max         1178.000000   1178.000000      1.074693e+06       1.085148e+06
#
#          YEAR BUILT  TAX CLASS AT TIME OF SALE   SALE\nPRICE
# count  15587.000000               15587.000000  1.558700e+04
# mean    1865.720408                   1.520434  5.519339e+05
# std      394.713209                   0.709699  1.997913e+06
# min        0.000000                   1.000000  1.000000e+00
# 25%     1928.000000                   1.000000  2.100000e+05
# 50%     1945.000000                   1.000000  3.725000e+05
# 75%     1960.000000                   2.000000  5.725000e+05
# max     2012.000000                   4.000000  1.130745e+08

# %%
#histrogram of SALE PRICE with log scale and no 0 values
num_bins = 100
plt.hist(df['SALE\nPRICE'], num_bins,facecolor='blue', alpha=0.7)
plt.hist(df['SALE\nPRICE'], log=True)
plt.xlabel('SALE\nPRICE') # label x-axis
plt.ylabel('Frequency') # label y-axis
plt.show()

# %%
#Scatterplot to demonstrate relationship between sale price (y) and gross square feet)
plt.scatter(df['GROSS SQUARE FEET'], df['SALE\nPRICE']) # generate scatterplot
plt.xlabel('GROSS SQUARE FEET') # label x-axis
plt.ylabel('SALE\nPRICE') # label y-axis
plt.show() # print plot

# %%
#I wanted to see what the graph and data would look like without the data point in the upper right
#to get a clearer picture of where the bulk of the points are
maxGross = df['GROSS SQUARE FEET'].idxmax()
maxSale = df['SALE\nPRICE'].idxmax()
df['GROSS SQUARE FEET'] = df['GROSS SQUARE FEET'].drop(maxGross)
df['SALE\nPRICE'] = df['SALE\nPRICE'].drop(maxGross)

# %%
#Scatterplot to demonstrate relationship between sale price (y) and gross square feet)
#with the outlier removed, there is a much closer look at the data.
#There may be some correlation, but without more analysis it is unclear.
#There may still be other outliers in the data set, but unable to tell without further calculations
plt.scatter(df['GROSS SQUARE FEET'], df['SALE\nPRICE']) # generate scatterplot
plt.xlabel('GROSS SQUARE FEET') # label x-axis
plt.ylabel('SALE\nPRICE') # label y-axis
plt.show() # print plot

# %%
#Search for only the family homes within the Building Class Category to generate a subset
familyhomes = df.loc[df['BUILDING CLASS CATEGORY'].str.contains("FAMILY HOMES")]
familyhomes.head()
# Out:
#     BOROUGH               NEIGHBORHOOD  \
# 0         4  AIRPORT LA GUARDIA
# 2         4  AIRPORT LA GUARDIA
# 5         4  AIRPORT LA GUARDIA
# 24        4  ARVERNE
# 27        4  ARVERNE
#
#                          BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0   01  ONE FAMILY HOMES                                            1    949
# 2   01  ONE FAMILY HOMES                                            1    976
# 5   02  TWO FAMILY HOMES                                            1    976
# 24  01  ONE FAMILY HOMES                                            1  15931
# 27  01  ONE FAMILY HOMES                                            1  15965
#
#     LOT EASE-MENT BUILDING CLASS AT PRESENT  \
# 0    30                                  A5
# 2    23                                  A5
# 5    21                                  B3
# 24   53                                  A5
# 27   90                                  A2
#
#                                       ADDRESS APART\nMENT\nNUMBER  ...  \
# 0   19-40 81ST STREET                                              ...
# 2   21-36 81ST   STREET                                            ...
# 5   21-32 81ST   STREET                                            ...
# 24  131 BEACH 59 STREET                                            ...
# 27  463 BEACH 43RD STREET                                          ...
#
#     RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  LAND SQUARE FEET  \
# 0                   1                 0            1              1800
# 2                   1                 0            1              1800
# 5                   2                 0            2              1800
# 24                  1                 0            1              1994
# 27                  1                 0            1              2604
#
#     GROSS SQUARE FEET  YEAR BUILT  TAX CLASS AT TIME OF SALE  \
# 0              1530.0        1945                          1
# 2              1224.0        1950                          1
# 5              1836.0        1950                          1
# 24              910.0        1975                          1
# 27             1784.0        1899                          1
#
#     BUILDING CLASS AT TIME OF SALE SALE\nPRICE  SALE DATE
# 0                               A5    620000.0 2013-05-13
# 2                               A5    505000.0 2013-02-13
# 5                               B3    540000.0 2013-05-23
# 24                              A5    131000.0 2013-07-12
# 27                              A2     95500.0 2012-08-24
#
# [5 rows x 21 columns]

# %%
#This scatterplot shows the relationship between gross square feet and price for 1, 2, and 3 family homes for the data set
plt.scatter(familyhomes['GROSS SQUARE FEET'], familyhomes['SALE\nPRICE'])
plt.xlabel('GROSS SQUARE FEET') # label x-axis
plt.ylabel('SALE\nPRICE') # label y-axis
plt.show() # print plot
